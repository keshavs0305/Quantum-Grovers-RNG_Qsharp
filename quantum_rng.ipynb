# %%
# !pip install qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-0.30.1.tar.gz (13 kB)
# Collecting qiskit-terra==0.18.3
#   Downloading qiskit_terra-0.18.3-cp36-cp36m-manylinux2010_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 33.4 MB/s eta 0:00:01
# Collecting qiskit-aer==0.9.0
#   Downloading qiskit_aer-0.9.0-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (17.9 MB)
#      |████████████████████████████████| 17.9 MB 87.1 MB/s eta 0:00:01
# Collecting qiskit-ibmq-provider==0.16.0
#   Downloading qiskit_ibmq_provider-0.16.0-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 113.5 MB/s eta 0:00:01
# Collecting qiskit-ignis==0.6.0
#   Downloading qiskit_ignis-0.6.0-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 110.0 MB/s eta 0:00:01
# Collecting qiskit-aqua==0.9.5
#   Downloading qiskit_aqua-0.9.5-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 112.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aer==0.9.0->qiskit) (1.19.5)
# Collecting pybind11>=2.6
#   Downloading pybind11-2.7.1-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 115.4 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aer==0.9.0->qiskit) (1.5.3)
# Collecting yfinance>=0.1.62
#   Downloading yfinance-0.1.63.tar.gz (26 kB)
# Collecting retworkx>=0.8.0
#   Downloading retworkx-0.10.2-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 96.0 MB/s eta 0:00:01
# Requirement already satisfied: psutil>=5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aqua==0.9.5->qiskit) (5.8.0)
# Requirement already satisfied: h5py<3.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aqua==0.9.5->qiskit) (3.1.0)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.1.5)
# Collecting dlx<=1.0.4
#   Downloading dlx-1.0.4.tar.gz (5.5 kB)
# Collecting fastdtw<=0.3.4
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
#      |████████████████████████████████| 133 kB 122.4 MB/s eta 0:00:01
# Requirement already satisfied: dataclasses in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.8)
# Collecting quandl
#   Downloading Quandl-3.6.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.24.1)
# Collecting docplex>=2.21.207
#   Downloading docplex-2.22.213.tar.gz (634 kB)
#      |████████████████████████████████| 634 kB 97.7 MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=40.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aqua==0.9.5->qiskit) (49.6.0.post20210108)
# Requirement already satisfied: sympy>=1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.7.1)
# Requirement already satisfied: urllib3>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-ibmq-provider==0.16.0->qiskit) (1.26.6)
# Requirement already satisfied: requests>=2.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-ibmq-provider==0.16.0->qiskit) (2.26.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-ibmq-provider==0.16.0->qiskit) (2.8.1)
# Collecting requests-ntlm>=1.1.0
#   Downloading requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
# Collecting websocket-client>=1.0.1
#   Using cached websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting symengine>0.7
#   Downloading symengine-0.8.1-cp36-cp36m-manylinux2010_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 101.0 MB/s eta 0:00:01
# Requirement already satisfied: jsonschema>=2.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-terra==0.18.3->qiskit) (3.2.0)
# Collecting tweedledum<2.0,>=1.1
#   Downloading tweedledum-1.1.1-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (943 kB)
#      |████████████████████████████████| 943 kB 92.6 MB/s eta 0:00:01
# Requirement already satisfied: dill>=0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-terra==0.18.3->qiskit) (0.3.4)
# Collecting python-constraint>=1.4
#   Downloading python-constraint-1.4.0.tar.bz2 (18 kB)
# Collecting fastjsonschema>=2.10
#   Downloading fastjsonschema-2.15.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: contextvars>=2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-terra==0.18.3->qiskit) (2.4)
# Requirement already satisfied: ply>=3.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from qiskit-terra==0.18.3->qiskit) (3.11)
# Requirement already satisfied: immutables>=0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from contextvars>=2.4->qiskit-terra==0.18.3->qiskit) (0.15)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docplex>=2.21.207->qiskit-aqua==0.9.5->qiskit) (1.15.0)
# Requirement already satisfied: cached-property in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from h5py<3.3.0->qiskit-aqua==0.9.5->qiskit) (1.5.1)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (3.7.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (20.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.16.0->qiskit) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.16.0->qiskit) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.16.0->qiskit) (2021.5.30)
# Collecting ntlm-auth>=1.0.2
#   Downloading ntlm_auth-1.5.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: cryptography>=1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.16.0->qiskit) (3.4.4)
# Requirement already satisfied: cffi>=1.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.16.0->qiskit) (1.14.5)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.16.0->qiskit) (2.20)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (1.0.1)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sympy>=1.3->qiskit-aqua==0.9.5->qiskit) (1.2.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Requirement already satisfied: lxml>=4.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from yfinance>=0.1.62->qiskit-aqua==0.9.5->qiskit) (4.6.3)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->qiskit-aqua==0.9.5->qiskit) (2021.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (3.10.0.2)
# Requirement already satisfied: more-itertools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from quandl->qiskit-aqua==0.9.5->qiskit) (8.7.0)
# Collecting inflection>=0.3.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Building wheels for collected packages: qiskit, dlx, docplex, fastdtw, python-constraint, yfinance, multitasking
#   Building wheel for qiskit (setup.py) ... done
#   Created wheel for qiskit: filename=qiskit-0.30.1-py3-none-any.whl size=11684 sha256=221a671027d96bdd2206bcceb90cc64cc8a0a9030b29a314e7e44a0a8479bd63
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/be/4c/98/534b51d01a440bea0642217654eb5bffef13ab5758266dcc65
#   Building wheel for dlx (setup.py) ... done
#   Created wheel for dlx: filename=dlx-1.0.4-py3-none-any.whl size=5709 sha256=2a6667a43fe916bde62482cc0d2bb841e09bf8d4b933d4c936727ac7b8f39027
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/ad/a3/52/859d389366d76e9e371e5a2dabefde5da7678c0032f008ca0a
#   Building wheel for docplex (setup.py) ... done
#   Created wheel for docplex: filename=docplex-2.22.213-py3-none-any.whl size=696852 sha256=4c2c191d7d309ebc2eede15f748ab3584e47f76318a4503b3937e0c706dadd40
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/d6/67/a1/49d2d21d233b7643aa2311eb4394666aa4f6bd983c3a217e36
#   Building wheel for fastdtw (setup.py) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-cp36-cp36m-linux_x86_64.whl size=404768 sha256=1c1cd23a884b1830af9f99ae721d61691cdefe4cbf4869d179e95703d11e0f8b
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/50/66/7a/7c98f31ea8ecc3a04a5b20ec6b48fbdf02c899034e95cc1ede
#   Building wheel for python-constraint (setup.py) ... done
#   Created wheel for python-constraint: filename=python_constraint-1.4.0-py2.py3-none-any.whl size=24079 sha256=c10116c0c083372934f2019e03ad3ba6381b4eaa2801bc0ba0bba46d021a9044
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/c2/e2/65/6222764e3e5b677acdb04b592abab7e15140a70baace656d81
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23909 sha256=d104616b45385a6ac0a5833a90acde9158fb0b613dee857ea87d8e09f534301d
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/8d/70/7b/987abb0c1e8a5b73008bdf47cbecd9df6dd145fa5f1ac27872
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=746b45f0154cd965771845fad9b244dd968057688ac762958f8da1747ea41306
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/5e/8a/c4/59c699498647c7c94b14c87a904ca7540646107b3d94b7c320
# Successfully built qiskit dlx docplex fastdtw python-constraint yfinance multitasking
# Installing collected packages: tweedledum, symengine, retworkx, python-constraint, fastjsonschema, qiskit-terra, ntlm-auth, multitasking, inflection, yfinance, websocket-client, requests-ntlm, quandl, qiskit-ignis, pybind11, fastdtw, docplex, dlx, qiskit-ibmq-provider, qiskit-aqua, qiskit-aer, qiskit
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.59.0
#     Uninstalling websocket-client-0.59.0:
#       Successfully uninstalled websocket-client-0.59.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# docker-compose 1.29.2 requires websocket-client<1,>=0.32.0, but you have websocket-client 1.2.1 which is incompatible.
# Successfully installed dlx-1.0.4 docplex-2.22.213 fastdtw-0.3.4 fastjsonschema-2.15.1 inflection-0.5.1 multitasking-0.0.9 ntlm-auth-1.5.0 pybind11-2.7.1 python-constraint-1.4.0 qiskit-0.30.1 qiskit-aer-0.9.0 qiskit-aqua-0.9.5 qiskit-ibmq-provider-0.16.0 qiskit-ignis-0.6.0 qiskit-terra-0.18.3 quandl-3.6.1 requests-ntlm-1.1.0 retworkx-0.10.2 symengine-0.8.1 tweedledum-1.1.1 websocket-client-1.2.1 yfinance-0.1.63

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute,IBMQ
from qiskit.tools.monitor import job_monitor

#IBMQ.enable_account('Enter API Key here')
provider = IBMQ.get_provider(hub='ibm-q')

n_qubits = 4
q = QuantumRegister(n_qubits,'q')
c = ClassicalRegister(n_qubits,'c')
circuit = QuantumCircuit(q,c)
circuit.h(q) # Applies hadamard gate to all qubits
circuit.measure(q,c) # Measures all qubits 

backend = provider.get_backend('ibmq_qasm_simulator')
job = execute(circuit, backend, shots=1)
                               
#print('Executing Job...\n')                 
job_monitor(job)
counts = job.result().get_counts()

print(counts.most_frequent())
print(int(counts.most_frequent(), 2))
# Out:
# Job Status: job has successfully run
# 0100
# 4
